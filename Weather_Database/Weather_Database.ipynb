# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=03069a1e2eb77d2fcc3c03de41c7f9af

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 747

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather['weather'][0]['description']
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description})
        

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | saint-leu
# Processing Record 3 of Set 1 | cape town
# Processing Record 4 of Set 1 | grindavik
# Processing Record 5 of Set 1 | gold coast
# Processing Record 6 of Set 1 | yuli
# Processing Record 7 of Set 1 | waipawa
# Processing Record 8 of Set 1 | komsomolskiy
# Processing Record 9 of Set 1 | busselton
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | keti bandar
# Processing Record 12 of Set 1 | atuona
# Processing Record 13 of Set 1 | castro
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | buchanan
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | kapaa
# Processing Record 18 of Set 1 | bredasdorp
# Processing Record 19 of Set 1 | whitley bay
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | tura
# Processing Record 22 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 1 | labuhan
# Processing Record 24 of Set 1 | jacksonville
# Processing Record 25 of Set 1 | hasaki
# Processing Record 26 of Set 1 | nikolskoye
# Processing Record 27 of Set 1 | mataura
# Processing Record 28 of Set 1 | belomorsk
# Processing Record 29 of Set 1 | bluff
# Processing Record 30 of Set 1 | arraial do cabo
# Processing Record 31 of Set 1 | upernavik
# Processing Record 32 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 33 of Set 1 | port hardy
# Processing Record 34 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 1 | meyungs
# City not found. Skipping...
# Processing Record 36 of Set 1 | cururupu
# Processing Record 37 of Set 1 | bambous virieux
# Processing Record 38 of Set 1 | vologda
# Processing Record 39 of Set 1 | mount isa
# Processing Record 40 of Set 1 | ponferrada
# Processing Record 41 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 1 | rikitea
# Processing Record 43 of Set 1 | sharan
# Processing Record 44 of Set 1 | sao gabriel da cachoeira
# Processing Record 45 of Set 1 | papara
# Processing Record 46 of Set 1 | pudozh
# Processing Record 47 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 1 | kirakira
# Processing Record 49 of Set 1 | verkh-usugli
# Processing Record 50 of Set 1 | sorkjosen
# Processing Record 1 of Set 2 | valparaiso
# Processing Record 2 of Set 2 | eydhafushi
# Processing Record 3 of Set 2 | laurel
# Processing Record 4 of Set 2 | east london
# Processing Record 5 of Set 2 | new norfolk
# Processing Record 6 of Set 2 | oyama
# Processing Record 7 of Set 2 | airai
# Processing Record 8 of Set 2 | raudeberg
# Processing Record 9 of Set 2 | georgetown
# Processing Record 10 of Set 2 | raymondville
# Processing Record 11 of Set 2 | hobart
# Processing Record 12 of Set 2 | kohlu
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 15 of Set 2 | kodiak
# Processing Record 16 of Set 2 | ust-ilimsk
# Processing Record 17 of Set 2 | sioux lookout
# Processing Record 18 of Set 2 | sakakah
# Processing Record 19 of Set 2 | pevek
# Processing Record 20 of Set 2 | san patricio
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | hithadhoo
# Processing Record 23 of Set 2 | isangel
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | puerto escondido
# Processing Record 26 of Set 2 | sosnogorsk
# Processing Record 27 of Set 2 | san cristobal
# Processing Record 28 of Set 2 | kemijarvi
# Processing Record 29 of Set 2 | albany
# Processing Record 30 of Set 2 | vao
# Processing Record 31 of Set 2 | prince rupert
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | cherskiy
# Processing Record 34 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 35 of Set 2 | lebu
# Processing Record 36 of Set 2 | saint george
# Processing Record 37 of Set 2 | khatanga
# Processing Record 38 of Set 2 | agadez
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 2 | magui
# City not found. Skipping...
# Processing Record 42 of Set 2 | ribeira grande
# Processing Record 43 of Set 2 | puerto ayora
# Processing Record 44 of Set 2 | tiksi
# Processing Record 45 of Set 2 | geraldton
# Processing Record 46 of Set 2 | le mans
# Processing Record 47 of Set 2 | esperance
# Processing Record 48 of Set 2 | mae sai
# Processing Record 49 of Set 2 | provideniya
# Processing Record 50 of Set 2 | avarua
# Processing Record 1 of Set 3 | wucheng
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | chapais
# Processing Record 4 of Set 3 | puerto leguizamo
# Processing Record 5 of Set 3 | kotelnich
# Processing Record 6 of Set 3 | ostrovnoy
# Processing Record 7 of Set 3 | jalu
# Processing Record 8 of Set 3 | sao caetano de odivelas
# Processing Record 9 of Set 3 | rawson
# Processing Record 10 of Set 3 | belyy yar
# Processing Record 11 of Set 3 | richards bay
# Processing Record 12 of Set 3 | waspan
# Processing Record 13 of Set 3 | sola
# Processing Record 14 of Set 3 | saint anthony
# Processing Record 15 of Set 3 | bandarbeyla
# Processing Record 16 of Set 3 | codrington
# Processing Record 17 of Set 3 | san jose
# Processing Record 18 of Set 3 | villa carlos paz
# Processing Record 19 of Set 3 | bordighera
# Processing Record 20 of Set 3 | ambulu
# Processing Record 21 of Set 3 | tieli
# Processing Record 22 of Set 3 | surt
# Processing Record 23 of Set 3 | vila
# Processing Record 24 of Set 3 | araguari
# Processing Record 25 of Set 3 | port elizabeth
# Processing Record 26 of Set 3 | mahon
# Processing Record 27 of Set 3 | namibe
# Processing Record 28 of Set 3 | watford
# Processing Record 29 of Set 3 | sao joao do paraiso
# Processing Record 30 of Set 3 | mar del plata
# Processing Record 31 of Set 3 | saskylakh
# Processing Record 32 of Set 3 | chokurdakh
# Processing Record 33 of Set 3 | male
# Processing Record 34 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 3 | kuandian
# Processing Record 36 of Set 3 | torbay
# Processing Record 37 of Set 3 | vestmanna
# Processing Record 38 of Set 3 | arlit
# Processing Record 39 of Set 3 | mozelos
# Processing Record 40 of Set 3 | santa barbara
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | battle creek
# Processing Record 43 of Set 3 | souillac
# Processing Record 44 of Set 3 | jamestown
# Processing Record 45 of Set 3 | norman wells
# Processing Record 46 of Set 3 | nelson bay
# Processing Record 47 of Set 3 | sitka
# Processing Record 48 of Set 3 | faya
# Processing Record 49 of Set 3 | pisco
# Processing Record 50 of Set 3 | luderitz
# Processing Record 1 of Set 4 | tasiilaq
# Processing Record 2 of Set 4 | naze
# Processing Record 3 of Set 4 | clyde river
# Processing Record 4 of Set 4 | yellowknife
# Processing Record 5 of Set 4 | nhulunbuy
# Processing Record 6 of Set 4 | cidreira
# Processing Record 7 of Set 4 | bulawayo
# Processing Record 8 of Set 4 | byron bay
# Processing Record 9 of Set 4 | genhe
# Processing Record 10 of Set 4 | ponta do sol
# Processing Record 11 of Set 4 | santa catarina de tepehuanes
# Processing Record 12 of Set 4 | eldikan
# City not found. Skipping...
# Processing Record 13 of Set 4 | salekhard
# Processing Record 14 of Set 4 | vestmannaeyjar
# Processing Record 15 of Set 4 | maloshuyka
# City not found. Skipping...
# Processing Record 16 of Set 4 | kavaratti
# Processing Record 17 of Set 4 | nanortalik
# Processing Record 18 of Set 4 | beringovskiy
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | ancud
# Processing Record 21 of Set 4 | nome
# Processing Record 22 of Set 4 | college
# Processing Record 23 of Set 4 | aflu
# City not found. Skipping...
# Processing Record 24 of Set 4 | mutsamudu
# City not found. Skipping...
# Processing Record 25 of Set 4 | margate
# Processing Record 26 of Set 4 | tongliao
# Processing Record 27 of Set 4 | dubbo
# Processing Record 28 of Set 4 | kavieng
# Processing Record 29 of Set 4 | bilma
# Processing Record 30 of Set 4 | naryshkino
# Processing Record 31 of Set 4 | oda
# Processing Record 32 of Set 4 | wuwei
# Processing Record 33 of Set 4 | muisne
# Processing Record 34 of Set 4 | tawnat
# City not found. Skipping...
# Processing Record 35 of Set 4 | semnan
# Processing Record 36 of Set 4 | vardo
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | allanmyo
# City not found. Skipping...
# Processing Record 39 of Set 4 | katherine
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | rio bueno
# Processing Record 42 of Set 4 | mehamn
# Processing Record 43 of Set 4 | palm valley
# Processing Record 44 of Set 4 | marsabit
# Processing Record 45 of Set 4 | porto-vecchio
# Processing Record 46 of Set 4 | nata
# Processing Record 47 of Set 4 | roald
# Processing Record 48 of Set 4 | olafsvik
# Processing Record 49 of Set 4 | florianopolis
# Processing Record 50 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 1 of Set 5 | emerald
# Processing Record 2 of Set 5 | batemans bay
# Processing Record 3 of Set 5 | alofi
# Processing Record 4 of Set 5 | jacksonville beach
# Processing Record 5 of Set 5 | broken hill
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | tautira
# Processing Record 8 of Set 5 | kununurra
# Processing Record 9 of Set 5 | nishihara
# Processing Record 10 of Set 5 | port moresby
# Processing Record 11 of Set 5 | ahipara
# Processing Record 12 of Set 5 | maragogi
# Processing Record 13 of Set 5 | otavi
# Processing Record 14 of Set 5 | saint-pierre
# Processing Record 15 of Set 5 | bethel
# Processing Record 16 of Set 5 | tessalit
# Processing Record 17 of Set 5 | alotau
# City not found. Skipping...
# Processing Record 18 of Set 5 | elizabeth city
# Processing Record 19 of Set 5 | tullahoma
# Processing Record 20 of Set 5 | cabedelo
# Processing Record 21 of Set 5 | kutum
# Processing Record 22 of Set 5 | assare
# Processing Record 23 of Set 5 | touros
# Processing Record 24 of Set 5 | mount gambier
# Processing Record 25 of Set 5 | eidfjord
# Processing Record 26 of Set 5 | umzimvubu
# City not found. Skipping...
# Processing Record 27 of Set 5 | poum
# Processing Record 28 of Set 5 | honningsvag
# Processing Record 29 of Set 5 | tukrah
# Processing Record 30 of Set 5 | sibolga
# Processing Record 31 of Set 5 | duz
# City not found. Skipping...
# Processing Record 32 of Set 5 | soyo
# Processing Record 33 of Set 5 | hambantota
# Processing Record 34 of Set 5 | kroya
# Processing Record 35 of Set 5 | dembi dolo
# Processing Record 36 of Set 5 | almaty
# Processing Record 37 of Set 5 | brae
# Processing Record 38 of Set 5 | chabahar
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | manokwari
# Processing Record 41 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 5 | sur
# Processing Record 43 of Set 5 | inirida
# Processing Record 44 of Set 5 | maloy
# Processing Record 45 of Set 5 | elat
# Processing Record 46 of Set 5 | along
# Processing Record 47 of Set 5 | sovetskiy
# Processing Record 48 of Set 5 | tuktoyaktuk
# Processing Record 49 of Set 5 | tilichiki
# Processing Record 50 of Set 5 | dharchula
# Processing Record 1 of Set 6 | panhala
# Processing Record 2 of Set 6 | nouadhibou
# Processing Record 3 of Set 6 | batagay
# Processing Record 4 of Set 6 | mayumba
# Processing Record 5 of Set 6 | chauk
# Processing Record 6 of Set 6 | port alfred
# Processing Record 7 of Set 6 | seoul
# Processing Record 8 of Set 6 | dikson
# Processing Record 9 of Set 6 | gladstone
# Processing Record 10 of Set 6 | dorado
# Processing Record 11 of Set 6 | hunza
# City not found. Skipping...
# Processing Record 12 of Set 6 | quatre cocos
# Processing Record 13 of Set 6 | palmer
# Processing Record 14 of Set 6 | mirandola
# Processing Record 15 of Set 6 | leningradskiy
# Processing Record 16 of Set 6 | malakal
# Processing Record 17 of Set 6 | warqla
# City not found. Skipping...
# Processing Record 18 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | san rafael
# Processing Record 20 of Set 6 | acapulco
# Processing Record 21 of Set 6 | guerrero negro
# Processing Record 22 of Set 6 | ilulissat
# Processing Record 23 of Set 6 | kaeo
# Processing Record 24 of Set 6 | half moon bay
# Processing Record 25 of Set 6 | pingzhuang
# Processing Record 26 of Set 6 | resistencia
# Processing Record 27 of Set 6 | ahuimanu
# Processing Record 28 of Set 6 | shenjiamen
# Processing Record 29 of Set 6 | lata
# Processing Record 30 of Set 6 | stykkisholmur
# Processing Record 31 of Set 6 | paamiut
# Processing Record 32 of Set 6 | chifeng
# Processing Record 33 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 6 | bonthe
# Processing Record 35 of Set 6 | kahului
# Processing Record 36 of Set 6 | vila franca do campo
# Processing Record 37 of Set 6 | santa rosa
# Processing Record 38 of Set 6 | denpasar
# Processing Record 39 of Set 6 | kasongo-lunda
# Processing Record 40 of Set 6 | jingdezhen
# Processing Record 41 of Set 6 | ust-maya
# Processing Record 42 of Set 6 | kangaba
# Processing Record 43 of Set 6 | saurimo
# Processing Record 44 of Set 6 | bengkulu
# Processing Record 45 of Set 6 | portland
# Processing Record 46 of Set 6 | mahbubabad
# Processing Record 47 of Set 6 | mildura
# Processing Record 48 of Set 6 | odweyne
# Processing Record 49 of Set 6 | lichinga
# Processing Record 50 of Set 6 | gornopravdinsk
# Processing Record 1 of Set 7 | armacao dos buzios
# City not found. Skipping...
# Processing Record 2 of Set 7 | lagoa
# Processing Record 3 of Set 7 | muroto
# Processing Record 4 of Set 7 | solginskiy
# Processing Record 5 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 6 of Set 7 | faanui
# Processing Record 7 of Set 7 | marquette
# Processing Record 8 of Set 7 | falealupo
# City not found. Skipping...
# Processing Record 9 of Set 7 | terra santa
# Processing Record 10 of Set 7 | buraydah
# Processing Record 11 of Set 7 | yar-sale
# Processing Record 12 of Set 7 | belmonte
# Processing Record 13 of Set 7 | sterling
# Processing Record 14 of Set 7 | westerly
# Processing Record 15 of Set 7 | punta alta
# Processing Record 16 of Set 7 | mahebourg
# Processing Record 17 of Set 7 | pitanga
# Processing Record 18 of Set 7 | hauterive
# Processing Record 19 of Set 7 | hami
# Processing Record 20 of Set 7 | bilibino
# Processing Record 21 of Set 7 | berlevag
# Processing Record 22 of Set 7 | kokopo
# Processing Record 23 of Set 7 | bandar-e lengeh
# Processing Record 24 of Set 7 | groningen
# Processing Record 25 of Set 7 | ngunguru
# Processing Record 26 of Set 7 | adrar
# Processing Record 27 of Set 7 | urubicha
# Processing Record 28 of Set 7 | mwinilunga
# Processing Record 29 of Set 7 | price
# Processing Record 30 of Set 7 | le vauclin
# Processing Record 31 of Set 7 | karasjok
# Processing Record 32 of Set 7 | boende
# Processing Record 33 of Set 7 | segezha
# Processing Record 34 of Set 7 | dingle
# Processing Record 35 of Set 7 | tromso
# Processing Record 36 of Set 7 | jijiga
# Processing Record 37 of Set 7 | qaqortoq
# Processing Record 38 of Set 7 | sorong
# Processing Record 39 of Set 7 | panguipulli
# Processing Record 40 of Set 7 | khovu-aksy
# Processing Record 41 of Set 7 | beloyarsk
# Processing Record 42 of Set 7 | pangnirtung
# Processing Record 43 of Set 7 | gangotri
# City not found. Skipping...
# Processing Record 44 of Set 7 | muragachha
# City not found. Skipping...
# Processing Record 45 of Set 7 | sukumo
# Processing Record 46 of Set 7 | mana
# Processing Record 47 of Set 7 | gorkovskoye
# City not found. Skipping...
# Processing Record 48 of Set 7 | araguacu
# Processing Record 49 of Set 7 | waycross
# Processing Record 50 of Set 7 | cayenne
# Processing Record 1 of Set 8 | zhezkazgan
# Processing Record 2 of Set 8 | karaton
# Processing Record 3 of Set 8 | bud
# Processing Record 4 of Set 8 | shanghai
# Processing Record 5 of Set 8 | sao filipe
# Processing Record 6 of Set 8 | izhevskoye
# Processing Record 7 of Set 8 | bucerias
# Processing Record 8 of Set 8 | hualmay
# Processing Record 9 of Set 8 | mahanoro
# Processing Record 10 of Set 8 | wanning
# Processing Record 11 of Set 8 | conceicao da barra
# Processing Record 12 of Set 8 | northam
# Processing Record 13 of Set 8 | asyut
# Processing Record 14 of Set 8 | uige
# Processing Record 15 of Set 8 | hofn
# Processing Record 16 of Set 8 | bonavista
# Processing Record 17 of Set 8 | chazuta
# Processing Record 18 of Set 8 | hornepayne
# Processing Record 19 of Set 8 | karaikkudi
# Processing Record 20 of Set 8 | lorengau
# Processing Record 21 of Set 8 | acarau
# Processing Record 22 of Set 8 | phalaborwa
# Processing Record 23 of Set 8 | mezen
# Processing Record 24 of Set 8 | hagere hiywet
# Processing Record 25 of Set 8 | cabo san lucas
# Processing Record 26 of Set 8 | bur gabo
# City not found. Skipping...
# Processing Record 27 of Set 8 | longyearbyen
# Processing Record 28 of Set 8 | wukari
# Processing Record 29 of Set 8 | bahir dar
# Processing Record 30 of Set 8 | rexburg
# Processing Record 31 of Set 8 | turayf
# Processing Record 32 of Set 8 | marakkanam
# Processing Record 33 of Set 8 | tubruq
# City not found. Skipping...
# Processing Record 34 of Set 8 | kibala
# Processing Record 35 of Set 8 | kingsport
# Processing Record 36 of Set 8 | gamba
# Processing Record 37 of Set 8 | preobrazheniye
# Processing Record 38 of Set 8 | neosho
# Processing Record 39 of Set 8 | kandi
# Processing Record 40 of Set 8 | omboue
# Processing Record 41 of Set 8 | pemangkat
# Processing Record 42 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 43 of Set 8 | galiwinku
# City not found. Skipping...
# Processing Record 44 of Set 8 | turukhansk
# Processing Record 45 of Set 8 | chamba
# Processing Record 46 of Set 8 | coihaique
# Processing Record 47 of Set 8 | buzmeyin
# Processing Record 48 of Set 8 | beyneu
# Processing Record 49 of Set 8 | mantua
# Processing Record 50 of Set 8 | victor harbor
# Processing Record 1 of Set 9 | ozernovskiy
# Processing Record 2 of Set 9 | tynda
# Processing Record 3 of Set 9 | qingyuan
# Processing Record 4 of Set 9 | kidal
# Processing Record 5 of Set 9 | sorland
# Processing Record 6 of Set 9 | derzhavinsk
# Processing Record 7 of Set 9 | scarborough
# Processing Record 8 of Set 9 | clarence town
# Processing Record 9 of Set 9 | corner brook
# Processing Record 10 of Set 9 | noumea
# Processing Record 11 of Set 9 | doha
# Processing Record 12 of Set 9 | leh
# Processing Record 13 of Set 9 | poronaysk
# Processing Record 14 of Set 9 | chany
# Processing Record 15 of Set 9 | marks
# Processing Record 16 of Set 9 | salalah
# Processing Record 17 of Set 9 | thinadhoo
# Processing Record 18 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 19 of Set 9 | santiago del estero
# Processing Record 20 of Set 9 | inhambane
# Processing Record 21 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 22 of Set 9 | blagoyevo
# Processing Record 23 of Set 9 | victoria
# Processing Record 24 of Set 9 | balagansk
# Processing Record 25 of Set 9 | lompoc
# Processing Record 26 of Set 9 | hay river
# Processing Record 27 of Set 9 | buta
# Processing Record 28 of Set 9 | tiznit
# Processing Record 29 of Set 9 | ampanihy
# Processing Record 30 of Set 9 | kapit
# Processing Record 31 of Set 9 | minudasht
# Processing Record 32 of Set 9 | khandyga
# Processing Record 33 of Set 9 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 34 of Set 9 | kovdor
# Processing Record 35 of Set 9 | vila velha
# Processing Record 36 of Set 9 | isoka
# Processing Record 37 of Set 9 | bambanglipuro
# Processing Record 38 of Set 9 | miura
# Processing Record 39 of Set 9 | yuci
# Processing Record 40 of Set 9 | husavik
# Processing Record 41 of Set 9 | beni mazar
# Processing Record 42 of Set 9 | jabiru
# City not found. Skipping...
# Processing Record 43 of Set 9 | piacabucu
# Processing Record 44 of Set 9 | ratnagiri
# Processing Record 45 of Set 9 | aykhal
# Processing Record 46 of Set 9 | uruguaiana
# Processing Record 47 of Set 9 | podsineye
# Processing Record 48 of Set 9 | asau
# Processing Record 49 of Set 9 | sisimiut
# Processing Record 50 of Set 9 | rio pardo de minas
# Processing Record 1 of Set 10 | gbadolite
# Processing Record 2 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 3 of Set 10 | sao joao de pirabas
# Processing Record 4 of Set 10 | mindelo
# Processing Record 5 of Set 10 | tecolutla
# Processing Record 6 of Set 10 | mahajanga
# Processing Record 7 of Set 10 | nirmal
# Processing Record 8 of Set 10 | caravelas
# Processing Record 9 of Set 10 | adelaide
# Processing Record 10 of Set 10 | hamilton
# Processing Record 11 of Set 10 | nueva helvecia
# Processing Record 12 of Set 10 | saldanha
# Processing Record 13 of Set 10 | kruisfontein
# Processing Record 14 of Set 10 | hobyo
# Processing Record 15 of Set 10 | ucluelet
# Processing Record 16 of Set 10 | york
# Processing Record 17 of Set 10 | vihti
# Processing Record 18 of Set 10 | kaitangata
# Processing Record 19 of Set 10 | lyantonde
# Processing Record 20 of Set 10 | pietarsaari
# Processing Record 21 of Set 10 | port lincoln
# Processing Record 22 of Set 10 | balaipungut
# Processing Record 23 of Set 10 | marietta
# Processing Record 24 of Set 10 | port blair
# Processing Record 25 of Set 10 | te anau
# Processing Record 26 of Set 10 | fortuna
# Processing Record 27 of Set 10 | klaksvik
# Processing Record 28 of Set 10 | anadyr
# Processing Record 29 of Set 10 | shingu
# Processing Record 30 of Set 10 | pueblo nuevo
# Processing Record 31 of Set 10 | at-bashi
# Processing Record 32 of Set 10 | bolshaya murta
# City not found. Skipping...
# Processing Record 33 of Set 10 | winnemucca
# Processing Record 34 of Set 10 | lashio
# Processing Record 35 of Set 10 | sunel
# Processing Record 36 of Set 10 | savonlinna
# Processing Record 37 of Set 10 | nenjiang
# Processing Record 38 of Set 10 | ust-uda
# Processing Record 39 of Set 10 | calvinia
# Processing Record 40 of Set 10 | mbala
# Processing Record 41 of Set 10 | atka
# City not found. Skipping...
# Processing Record 42 of Set 10 | bathsheba
# Processing Record 43 of Set 10 | coaldale
# Processing Record 44 of Set 10 | makinsk
# Processing Record 45 of Set 10 | pokhara
# Processing Record 46 of Set 10 | fort nelson
# Processing Record 47 of Set 10 | shache
# Processing Record 48 of Set 10 | juba
# Processing Record 49 of Set 10 | shirokiy
# Processing Record 50 of Set 10 | ossora
# Processing Record 1 of Set 11 | naryan-mar
# Processing Record 2 of Set 11 | eskasem
# City not found. Skipping...
# Processing Record 3 of Set 11 | port-cartier
# Processing Record 4 of Set 11 | mamallapuram
# Processing Record 5 of Set 11 | moyobamba
# Processing Record 6 of Set 11 | koryazhma
# Processing Record 7 of Set 11 | verkhnetulomskiy
# Processing Record 8 of Set 11 | jiuquan
# Processing Record 9 of Set 11 | bundaberg
# Processing Record 10 of Set 11 | vila do maio
# Processing Record 11 of Set 11 | traverse city
# Processing Record 12 of Set 11 | carroll
# Processing Record 13 of Set 11 | totness
# Processing Record 14 of Set 11 | ypsonas
# Processing Record 15 of Set 11 | pirovskoye
# Processing Record 16 of Set 11 | champerico
# Processing Record 17 of Set 11 | san felipe
# Processing Record 18 of Set 11 | kadykchan
# City not found. Skipping...
# Processing Record 19 of Set 11 | nanakuli
# Processing Record 20 of Set 11 | shimoda
# Processing Record 21 of Set 11 | mustasaari
# Processing Record 22 of Set 11 | lujiang
# Processing Record 23 of Set 11 | yangjiang
# Processing Record 24 of Set 11 | aguimes
# Processing Record 25 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 26 of Set 11 | ilebo
# Processing Record 27 of Set 11 | marystown
# Processing Record 28 of Set 11 | kon tum
# Processing Record 29 of Set 11 | teneguiban
# City not found. Skipping...
# Processing Record 30 of Set 11 | oxbow
# Processing Record 31 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 32 of Set 11 | verkhnevilyuysk
# Processing Record 33 of Set 11 | los llanos de aridane
# Processing Record 34 of Set 11 | raton
# Processing Record 35 of Set 11 | siavonga
# Processing Record 36 of Set 11 | pendleton
# Processing Record 37 of Set 11 | shush
# Processing Record 38 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 39 of Set 11 | trat
# Processing Record 40 of Set 11 | pushkino
# Processing Record 41 of Set 11 | barcelos
# Processing Record 42 of Set 11 | jurm
# Processing Record 43 of Set 11 | malyye derbety
# Processing Record 44 of Set 11 | maraa
# Processing Record 45 of Set 11 | narsaq
# Processing Record 46 of Set 11 | ahlat
# Processing Record 47 of Set 11 | sambava
# Processing Record 48 of Set 11 | toftir
# City not found. Skipping...
# Processing Record 49 of Set 11 | arman
# Processing Record 50 of Set 11 | gravdal
# Processing Record 1 of Set 12 | kostomuksha
# Processing Record 2 of Set 12 | lumeje
# Processing Record 3 of Set 12 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 5 of Set 12 | kosino
# Processing Record 6 of Set 12 | harper
# Processing Record 7 of Set 12 | egvekinot
# Processing Record 8 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 12 | suruc
# Processing Record 10 of Set 12 | kalianget
# Processing Record 11 of Set 12 | bo phloi
# Processing Record 12 of Set 12 | axim
# Processing Record 13 of Set 12 | paytug
# City not found. Skipping...
# Processing Record 14 of Set 12 | lasa
# Processing Record 15 of Set 12 | sinnamary
# Processing Record 16 of Set 12 | novopavlovsk
# Processing Record 17 of Set 12 | semey
# Processing Record 18 of Set 12 | klyuchi
# Processing Record 19 of Set 12 | uryupinsk
# Processing Record 20 of Set 12 | haapiti
# Processing Record 21 of Set 12 | scottsburgh
# City not found. Skipping...
# Processing Record 22 of Set 12 | colares
# Processing Record 23 of Set 12 | ormara
# Processing Record 24 of Set 12 | kemin
# Processing Record 25 of Set 12 | shiyan
# Processing Record 26 of Set 12 | djambala
# Processing Record 27 of Set 12 | gat
# Processing Record 28 of Set 12 | kieta
# Processing Record 29 of Set 12 | pahrump
# Processing Record 30 of Set 12 | muros
# Processing Record 31 of Set 12 | shangzhi
# Processing Record 32 of Set 12 | sao joao do piaui
# Processing Record 33 of Set 12 | borovoy
# Processing Record 34 of Set 12 | kearney
# Processing Record 35 of Set 12 | vernon
# Processing Record 36 of Set 12 | meulaboh
# Processing Record 37 of Set 12 | necochea
# Processing Record 38 of Set 12 | xapuri
# Processing Record 39 of Set 12 | nova olimpia
# Processing Record 40 of Set 12 | dahuk
# Processing Record 41 of Set 12 | biak
# Processing Record 42 of Set 12 | mergui
# City not found. Skipping...
# Processing Record 43 of Set 12 | deer lake
# Processing Record 44 of Set 12 | sao felix do xingu
# Processing Record 45 of Set 12 | marshall
# Processing Record 46 of Set 12 | oranjestad
# Processing Record 47 of Set 12 | kasangulu
# Processing Record 48 of Set 12 | broome
# Processing Record 49 of Set 12 | dalmatovo
# Processing Record 50 of Set 12 | saint-georges
# Processing Record 1 of Set 13 | sabha
# Processing Record 2 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 3 of Set 13 | sheopur
# Processing Record 4 of Set 13 | caraguatatuba
# Processing Record 5 of Set 13 | churapcha
# Processing Record 6 of Set 13 | cayambe
# Processing Record 7 of Set 13 | yulara
# Processing Record 8 of Set 13 | dryden
# Processing Record 9 of Set 13 | khash
# Processing Record 10 of Set 13 | terrace
# Processing Record 11 of Set 13 | amuntai
# Processing Record 12 of Set 13 | verkhnyaya inta
# Processing Record 13 of Set 13 | danjiangkou
# Processing Record 14 of Set 13 | chulman
# Processing Record 15 of Set 13 | nuuk
# Processing Record 16 of Set 13 | kloulklubed
# Processing Record 17 of Set 13 | dunedin
# Processing Record 18 of Set 13 | coquimbo
# Processing Record 19 of Set 13 | calama
# Processing Record 20 of Set 13 | oum hadjer
# Processing Record 21 of Set 13 | pontes e lacerda
# Processing Record 22 of Set 13 | kupang
# Processing Record 23 of Set 13 | baruun-urt
# Processing Record 24 of Set 13 | buon me thuot
# City not found. Skipping...
# Processing Record 25 of Set 13 | torres
# Processing Record 26 of Set 13 | laguna
# Processing Record 27 of Set 13 | vostok
# Processing Record 28 of Set 13 | vanimo
# Processing Record 29 of Set 13 | kewanee
# Processing Record 30 of Set 13 | umm lajj
# Processing Record 31 of Set 13 | lewistown
# Processing Record 32 of Set 13 | carbonia
# Processing Record 33 of Set 13 | sinop
# Processing Record 34 of Set 13 | iracoubo
# Processing Record 35 of Set 13 | le port
# Processing Record 36 of Set 13 | palana
# Processing Record 37 of Set 13 | quimper
# Processing Record 38 of Set 13 | normandin
# Processing Record 39 of Set 13 | sao geraldo do araguaia
# Processing Record 40 of Set 13 | kashi
# Processing Record 41 of Set 13 | el alto
# Processing Record 42 of Set 13 | araouane
# Processing Record 43 of Set 13 | clinton
# Processing Record 44 of Set 13 | pochutla
# Processing Record 45 of Set 13 | migori
# Processing Record 46 of Set 13 | jiwani
# Processing Record 47 of Set 13 | tambun
# Processing Record 48 of Set 13 | cockburn harbour
# City not found. Skipping...
# Processing Record 49 of Set 13 | mahibadhoo
# Processing Record 50 of Set 13 | abidjan
# Processing Record 1 of Set 14 | grenaa
# Processing Record 2 of Set 14 | narsimhapur
# Processing Record 3 of Set 14 | lodja
# Processing Record 4 of Set 14 | eureka
# Processing Record 5 of Set 14 | bani walid
# Processing Record 6 of Set 14 | areosa
# Processing Record 7 of Set 14 | inuvik
# Processing Record 8 of Set 14 | corrente
# Processing Record 9 of Set 14 | kukes
# Processing Record 10 of Set 14 | rawannawi
# City not found. Skipping...
# Processing Record 11 of Set 14 | aksarka
# Processing Record 12 of Set 14 | mega
# Processing Record 13 of Set 14 | whitianga
# Processing Record 14 of Set 14 | shuyskoye
# Processing Record 15 of Set 14 | kondoros
# Processing Record 16 of Set 14 | evanton
# Processing Record 17 of Set 14 | alice springs
# Processing Record 18 of Set 14 | taltal
# Processing Record 19 of Set 14 | okhotsk
# Processing Record 20 of Set 14 | kiama
# Processing Record 21 of Set 14 | hervey bay
# Processing Record 22 of Set 14 | huarmey
# Processing Record 23 of Set 14 | goderich
# Processing Record 24 of Set 14 | fuchu
# Processing Record 25 of Set 14 | pitimbu
# Processing Record 26 of Set 14 | vilhena
# Processing Record 27 of Set 14 | novo aripuana
# Processing Record 28 of Set 14 | homer
# Processing Record 29 of Set 14 | dyersburg
# Processing Record 30 of Set 14 | astana
# Processing Record 31 of Set 14 | kutoarjo
# Processing Record 32 of Set 14 | qasigiannguit
# Processing Record 33 of Set 14 | lavrentiya
# Processing Record 34 of Set 14 | arroyo
# Processing Record 35 of Set 14 | farah
# Processing Record 36 of Set 14 | kaabong
# Processing Record 37 of Set 14 | peniche
# Processing Record 38 of Set 14 | dianopolis
# City not found. Skipping...
# Processing Record 39 of Set 14 | khorramshahr
# Processing Record 40 of Set 14 | ambon
# Processing Record 41 of Set 14 | lufilufi
# Processing Record 42 of Set 14 | alma
# Processing Record 43 of Set 14 | constitucion
# Processing Record 44 of Set 14 | ca mau
# Processing Record 45 of Set 14 | sao joao da barra
# Processing Record 46 of Set 14 | sept-iles
# Processing Record 47 of Set 14 | kochki
# Processing Record 48 of Set 14 | north bend
# Processing Record 49 of Set 14 | ciurila
# Processing Record 50 of Set 14 | dolbeau
# City not found. Skipping...
# Processing Record 1 of Set 15 | mayo
# Processing Record 2 of Set 15 | ixtapa
# Processing Record 3 of Set 15 | sabzevar
# Processing Record 4 of Set 15 | henties bay
# Processing Record 5 of Set 15 | muli
# Processing Record 6 of Set 15 | campos belos
# Processing Record 7 of Set 15 | prabumulih
# Processing Record 8 of Set 15 | vuktyl
# Processing Record 9 of Set 15 | maues
# Processing Record 10 of Set 15 | saint-francois
# Processing Record 11 of Set 15 | praia da vitoria
# Processing Record 12 of Set 15 | magdagachi
# Processing Record 13 of Set 15 | mao
# Processing Record 14 of Set 15 | bereda
# Processing Record 15 of Set 15 | bogale
# Processing Record 16 of Set 15 | karratha
# Processing Record 17 of Set 15 | imeni poliny osipenko
# Processing Record 18 of Set 15 | yirol
# City not found. Skipping...
# Processing Record 19 of Set 15 | san ramon
# Processing Record 20 of Set 15 | walvis bay
# Processing Record 21 of Set 15 | albanel
# Processing Record 22 of Set 15 | yima
# Processing Record 23 of Set 15 | makakilo city
# Processing Record 24 of Set 15 | hirara
# Processing Record 25 of Set 15 | bowen
# Processing Record 26 of Set 15 | coari
# Processing Record 27 of Set 15 | flinders
# Processing Record 28 of Set 15 | murray bridge
# Processing Record 29 of Set 15 | kissidougou
# Processing Record 30 of Set 15 | coahuayana
# Processing Record 31 of Set 15 | ponta delgada
# Processing Record 32 of Set 15 | ulladulla
# Processing Record 33 of Set 15 | padang
# Processing Record 34 of Set 15 | bloemfontein
# Processing Record 35 of Set 15 | golden
# Processing Record 36 of Set 15 | natitingou
# Processing Record 37 of Set 15 | chimbote
# Processing Record 38 of Set 15 | islamkot
# Processing Record 39 of Set 15 | riyadh
# Processing Record 40 of Set 15 | port-gentil
# Processing Record 41 of Set 15 | spring hill
# Processing Record 42 of Set 15 | zinder
# Processing Record 43 of Set 15 | roma
# Processing Record 44 of Set 15 | pouembout
# Processing Record 45 of Set 15 | bahia blanca
# Processing Record 46 of Set 15 | shahr-e babak
# Processing Record 47 of Set 15 | camana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head()
# Out:
#          City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    Hermanus      ZA -34.4187   19.2345     61.81        87           1
# 1   Saint-Leu      RE -21.1500   55.2833     74.26        79          99
# 2   Cape Town      ZA -33.9258   18.4232     64.90        81           0
# 3   Grindavik      IS  63.8424  -22.4338     40.95       100          75
# 4  Gold Coast      AU -28.0000  153.4333     71.01        90          75
#
#    Wind Speed Current Description
# 0        8.59           clear sky
# 1        2.26          light rain
# 2       13.80           clear sky
# 3       16.11       broken clouds
# 4        6.91       broken clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
